# %%
import pandas as pd
import numpy as np
from pandas import json_normalize
import requests
import json

# %% [markdown]
# # Tweepy

# %%
df = pd.read_csv('api_s.csv')
df
# Out:
#                 consumer_key  \
# 0  qTi2G4s8zuybhF5LReyIGvQpx
#
#                                      consumer_secret  \
# 0  a0nj2L7DRz3LktHhei4nG7y4ymNnDD7LiIqQmLnw3thzN4...
#
#                                         bearer_token  \
# 0  AAAAAAAAAAAAAAAAAAAAAJkHNQEAAAAAqsEpKXKU8XlNgr...
#
#                                         access_token  \
# 0  740937600475795456-rDP7E53ht8AalwPMgNMYohUv4VF...
#
#                              access_token_secret  \
# 0  yETFBKuwYcKxt6a246GeBOBsNCYBVc46aV5wqzEt3Tx7D
#
#                           coinmarketcap
# 0  71e8ae85-d1b5-45e9-a6e7-fa65d58fabcc

# %%
# tweepy
consumer_key = df['consumer_key'][0]
consumer_secret = df['consumer_secret'][0]
access_token = df['access_token'][0]
access_token_secret = df['access_token_secret'][0]
# coinmarketcap
coin_key = df['coinmarketcap'][0]

# %% [markdown]
# tweepy

# %%
import tweepy

# Authenticate to Twitter
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

# %%
# Create API object
api = tweepy.API(auth)

# %%
# Verify credentials:
try:
    api.verify_credentials()
    print("Authentication OK")
except:
    print("Error during authentication")
# Out:
# Authentication OK

# %% [markdown]
# Probably I am going to use the category:
#
# * methods for User Timelines
# * Methods for Users
# * Methods for Search (in all accounts)
# * Methods for Streaming

# %%
# Method for trends.
trends_result = api.trends_place(1)
for trend in trends_result[0]['trends']:
    print(trend['name'])
# Out:
# #MCIMUN
# #BTSGrammyPerformers
# PROUD OF HARRY
# #Teşkilat
# Martial
# Manchester is Red
# #MUFC
# #StrayKids_GodsMenu200M
# Shaw
# BTS WORLD DOMINATION
# Liverpool
# WHAT YOONGI WANTS YOONGI GETS
# Madrid
# TEAMWORK MAKES THE DREAM WORK
# Benzema
# Foden
# Man City
# Rashford
# Marquinhos Gabriel
# Fulham
# Hernández Hernández
# FECHADOS COM JULIETTE
# Klopp
# Olivier Dassault
# Henderson
# Sterling
# Linnes
# Pazartesi Mebdenİlemri
# Casemiro
# Mahrez
# Haftanın Yalanları
# Bangtan
# Etihad
# Falcao
# Anfield
# Fatih Terim
# Doja
# De Bruyne
# Gabriel Jesus
# Oblak
# LO LOGRARON
# Ernando
# Ganso
# Megan
# Boyd
# Bruno Fernandes
# HAPPY 200M GOD'S MENU MV
# McTominay
# Babel
# Mumford

# %%
# method for user timelines
# My timeline 20 elements.
'''timeline = api.home_timeline()
for tweet in timeline:
    print(f"{tweet.user.name} said {tweet.text}")'''
# Out:
# 'timeline = api.home_timeline()\nfor tweet in timeline:\n    print(f"{tweet.user.name} said {tweet.text}")'

# %%
# Methods for Users:

user = api.get_user("elonmusk")

print("User details:")
print(user.name)
print(user.description)
print(user.location)

print("Last 20 Followers:")
for follower in user.followers():
    print(follower.name)
# Out:
# User details:
# Elon Musk
#
#
# Last 20 Followers:
# Iosif Rossolatos
# Ben
# Ty
# Troy
# Melinda Gorden
# Danijel
# MarlaRattan
# Jon Velez
# erfanamiri
# Paul Dunn
# Dilshod Davlatboev
# Håvard Moland
# serfan
# Tibetan Cafe
# Krozzy
# Nilo García
# Nour Florita
# Rene guatemalteco 100%100
# Shemar Gibson
# Polaro

# %%
# Methods for Search 

for tweet in api.search(q="crypto", lang="en", rpp=10):
    print(f"{tweet.user.name}:{tweet.text}")
# Out:
# SSJGOOSE:@Bitboy_Crypto I'm not taking any chances and getting out end of August if I'm significantly up. Rather miss out on… https://t.co/5t5cnAcb0y
# Alpha Tweets:@Bitboy_Crypto Even if it ends the low will still be higher than current price so why worry ? The lowest it will get is 60k
# Michael Bryan:@Bitboy_Crypto Without a bear market, you can’t have bull runs. Ying and Yang.
# Goat In Charge:RT @mszmidt1210: ☄️ #Pulse Network #Airdrop
# 💵 Total #Prize Pool $30000 PULSE
#
# 🛡Airdrop link 👉 https://t.co/8EcRA8cq0v
# 1. Retweet + Like
# #C…
# AnatoleSerial (アナトール・シリアル):RT @thatskidding: i cant stop reading @Personfaces's thorough and thoughtful take on crypto art https://t.co/No8Gz2EkQY
# Toshi Satoshi:#Crypto Top Losers (7D) 🍯
#
# $MDX Mdex $4.70 (-18.91%)
# $ADA Cardano $1.12 (-16.56%)
# $AMP Amp $0.0213 (-10.39%)
# $1INCH… https://t.co/3cPRoTMVRV
# ...

# %% [raw]
# # Methods for Streaming
#
# import json
# import tweepy
#
# class MyStreamListener(tweepy.StreamListener):
#     def __init__(self, api):
#         self.api = api
#         self.me = api.me()
#
#     def on_status(self, tweet):
#         print(f"{tweet.user.name}:{tweet.text}")
#
#     def on_error(self, status):
#         print("Error detected")
#
# # Authenticate to Twitter
# auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
# auth.set_access_token(access_token, access_token_secret)
#
# # Create API object
# api = tweepy.API(auth, wait_on_rate_limit=True,
#     wait_on_rate_limit_notify=True)
#
# tweets_listener = MyStreamListener(api)
# stream = tweepy.Stream(api.auth, tweets_listener)
# stream.filter(track=["crypto", "profit"], languages=["en"])

# %%
# inspectin a tweets json
public_tweets = api.home_timeline()
public_tweets[0]
# Out:
# Status(_api=<tweepy.api.API object at 0x0000026EF781EAF0>, _json={'created_at': 'Sun Mar 07 19:41:11 +0000 2021', 'id': 1368647936788205568, 'id_str': '1368647936788205568', 'text': '[...] una patria integrada por ciudadanos conscientes para quienes la libertad es la única atmósfera respirable, y… https://t.co/eVTH9iMJVj', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/eVTH9iMJVj', 'expanded_url': 'https://twitter.com/i/web/status/1368647936788205568', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [116, 139]}]}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': 1368647935630606336, 'in_reply_to_status_id_str': '1368647935630606336', 'in_reply_to_user_id': 55628839, 'in_reply_to_user_id_str': '55628839', 'in_reply_to_screen_name': 'cultura_mx', 'user': {'id': 55628839, 'id_str': '55628839', 'name': 'Secretaría de Cultura', 'screen_name': 'cultura_m
# ...

# %%
import json

status = public_tweets[0]

# convert to string
json_str = json.dumps(status._json)

#deserialise string into python objet
parsed = json.loads(json_str)

print(json.dumps(parsed,indent=4, sort_keys=True))
# Out:
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Sun Mar 07 19:41:11 +0000 2021",
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "urls": [
#             {
#                 "display_url": "twitter.com/i/web/status/1\u2026",
#                 "expanded_url": "https://twitter.com/i/web/status/1368647936788205568",
#                 "indices": [
#                     116,
#                     139
#                 ],
#                 "url": "https://t.co/eVTH9iMJVj"
#             }
#         ],
#         "user_mentions": []
#     },
#     "favorite_count": 0,
#     "favorited": false,
#     "geo": null,
#     "id": 1368647936788205568,
#     "id_str": "1368647936788205568",
#     "in_reply_to_screen_name": "cultura_mx",
#     "in_reply_to_status_id": 1368647935630606336,
#     "in_reply_to_status_id_str": "1368647935630606336",
#     "in_reply_to_user_id": 55628839,
#     "in_reply_to_user_id_str": "55628839",
# ...

# %%
status.text
# Out:
# '[...] una patria integrada por ciudadanos conscientes para quienes la libertad es la única atmósfera respirable, y… https://t.co/eVTH9iMJVj'

# %% [markdown]
# # Marketcap

# %%
#This example uses Python 2.7 and the python-request library.

from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
#import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'500',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': coin_key,
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2021-03-07T19:41:18.832Z', 'error_code': 0, 'error_message': None, 'elapsed': 31, 'credit_count': 3, 'notice': None, 'total_count': 4257}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 9811, 'date_added': '2013-04-28T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channels', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio'], 'max_supply': 21000000, 'circulating_supply': 18647425, 'total_supply': 18647425, 'platform': None, 'cmc_rank': 1, 'last_updated': '2021-03-07T19:39:02.000Z', 'quote': {'USD': {'price': 50508.984348517064, 'volume_24h': 42037113465.66051, 'percent_change_1h': -0.95644282, 'percent_change_24h': 4.49348562, 'percent_change_7d': 16.14040186, 'percent_change_30d': 34.01813964, 'percent_change_60d': 43.22021344, 'percent_change_90d': 165.82536762, 'market_cap': 941862497465.1459, 'last_updated': '2021-03-07T19:39:02.00
# ...

# %%
type(data)
# Out:
# dict

# %%
data.keys()
column_list = ['status', 'data']

# %%
data_normalized = pd.json_normalize(data)

# %%
data_normalized
# Out:
#                                                 data  \
# 0  [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC',...
#
#            status.timestamp  status.error_code status.error_message  \
# 0  2021-03-07T19:41:18.832Z                  0                 None
#
#    status.elapsed  status.credit_count status.notice  status.total_count
# 0              31                    3          None                4257

# %%
# Flattening of the data

def flatten(data, col_list):
    for column in col_list:
        flattened = pd.DataFrame(dict(data[column])).transpose()
        columns = [str(col) for col in flattened.columns]
        flattened.columns = [column + '_' + colname for colname in columns]
        data = pd.concat([data, flattened], axis=1)
        data = data.drop(column, axis=1)
    return data

# %%
nested_columns = ['data']

flatten(data_normalized, nested_columns)
# Out:
#            status.timestamp  status.error_code status.error_message  \
# 0  2021-03-07T19:41:18.832Z                  0                 None
#
#    status.elapsed  status.credit_count status.notice  status.total_count  \
# 0              31                    3          None                4257
#
#                                               data_0  \
# 0  {'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', ...
#
#                                               data_1  \
# 0  {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...
#
#                                               data_2  ...  \
# 0  {'id': 825, 'name': 'Tether', 'symbol': 'USDT'...  ...
#
#                                             data_490  \
# 0  {'id': 4090, 'name': 'Wirex Token', 'symbol': ...
#
#                                             data_491  \
# 0  {'id': 7412, 'name': 'UniLend', 'symbol': 'UFT...
#
#                                             data_492  \
# 0  {'id': 2313, 'name': 'SIRIN LABS Token', 'symb...
#
# ...

# %% [markdown]
# endpoints que posiblemente utilice:
#
# * cryptocurrency
# * tools

# %% [markdown]
# # Yahoo dataset

# %%
btc_usd = pd.read_csv('BTC-USD.csv')

# %%
btc_usd.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2014-09-17  465.864014  468.174011  452.421997  457.334015  457.334015
# 1  2014-09-18  456.859985  456.859985  413.104004  424.440002  424.440002
# 2  2014-09-19  424.102997  427.834991  384.532013  394.795990  394.795990
# 3  2014-09-20  394.673004  423.295990  389.882996  408.903992  408.903992
# 4  2014-09-21  408.084991  412.425995  393.181000  398.821014  398.821014
#
#        Volume
# 0  21056800.0
# 1  34483200.0
# 2  37919700.0
# 3  36863600.0
# 4  26580100.0

# %%
btc_usd.tail()
# Out:
#             Date          Open          High           Low         Close  \
# 2358  2021-03-02  49612.105469  50127.511719  47228.843750  48378.988281
# 2359  2021-03-03  48415.816406  52535.136719  48274.320313  50538.242188
# 2360  2021-03-04  50522.304688  51735.089844  47656.929688  48561.167969
# 2361  2021-03-05  48527.031250  49396.429688  46542.515625  48927.304688
# 2362  2021-03-06  48555.796875  49142.058594  47270.699219  48503.964844
#
#          Adj Close        Volume
# 2358  48378.988281  4.753090e+10
# 2359  50538.242188  5.322081e+10
# 2360  48561.167969  5.234382e+10
# 2361  48927.304688  4.862593e+10
# 2362  48503.964844  3.437822e+10

# %%
btc_usd = btc_usd.drop(labels=['Adj Close','Open','High','Low'],axis=1)

# %%
btc_usd.rename(columns={'Close':'Price'}, inplace = True)

# %%
btc_usd.shape
# Out:
# (2363, 3)
