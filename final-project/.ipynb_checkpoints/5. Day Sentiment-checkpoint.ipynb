# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data.columns
# Out:
# Index(['name', 'retweet_count', 'text', 'created_at', 'favourite_count',
#        'hashtags', 'sentiment_a', 'stopwords', 'clean_words', 'polarity',
#        'sentiment'],
#       dtype='object')

# %%
data = pd.read_csv('clean_tweets.csv')
# Out:
#    name  retweet_count                                               text  \
# 0  Pomp              0                                              wild
# 1  Pomp            125  rt  if you had invested your 1200 stimulus che...
# 2  Pomp              3            how is your paper trading account going
# 3  Pomp            132  update gamestop closed today at 194 per share ...
# 4  Pomp              6  rt   daily letter this morning is pretty spot ...
#
#    created_at  favourite_count hashtags  \
# 0  2021-03-08               61       []
# 1  2021-03-08                0       []
# 2  2021-03-08               86       []
# 3  2021-03-08             1906       []
# 4  2021-03-08                0       []
#
#                                          sentiment_a  \
# 0                                           ['wild']
# 1  ['rt', 'if', 'you', 'had', 'invested', 'your',...
# 2  ['how', 'is', 'your', 'paper', 'trading', 'acc...
# 3  ['update', 'gamestop', 'closed', 'today', 'at'...
# 4  ['rt', 'daily', 'letter', 'this', 'morning', '...
#
#                                            stopwords  \
# 0  ['i', 'me', 'my', 'myself', 'we', 'our', 'ours...
# 1  ['i', 'me', 'my', 'myself', 'we', 'our', 'ours...
# 2  ['i', 'me', 'my', 'myself', 'we', 'our', 'ours...
# 3  ['i', 'me', 'my', 'myself', 'we', 'our', 'ours...
# 4  ['i', 'me', 'my', 'myself', 'we', 'our', 'ours...
#
#                                          clean_words  polarity sentiment
# 0                                         [' wild ']  0.100000  positive
# 1  ['if you had invested your 1200 stimulus check...  0.000000   neutral
# 2       [' how is your paper trading account going']  0.000000   neutral
# 3  ['update gamestop closed today at 194 per shar...  0.100000  positive
# 4  ['daily letter this morning is pretty spot on ...  0.083333  positive

# %% [markdown]
# # New df containing just sentiments

# %%
new_df = data[['retweet_count', 'created_at','sentiment']].copy()

# %%
new_df
# Out:
#        retweet_count  created_at sentiment
# 0                  0  2021-03-08  positive
# 1                125  2021-03-08   neutral
# 2                  3  2021-03-08   neutral
# 3                132  2021-03-08  positive
# 4                  6  2021-03-08  positive
# ...              ...         ...       ...
# 24336             21  2017-05-29   neutral
# 24337              0  2017-05-29  positive
# 24338             76  2017-05-29  positive
# 24339              0  2017-05-29   neutral
# 24340              0  2017-05-29  positive
#
# [24341 rows x 3 columns]

# %%
new_df[['positive', 'neutral', 'negative']] = pd.DataFrame([[0,0,0]])

# %%
new_df
# Out:
#        retweet_count  created_at sentiment  positive  neutral  negative
# 0                  0  2021-03-08  positive         1        0         0
# 1                125  2021-03-08   neutral         0      126         0
# 2                  3  2021-03-08   neutral         0        4         0
# 3                132  2021-03-08  positive       133        0         0
# 4                  6  2021-03-08  positive         7        0         0
# ...              ...         ...       ...       ...      ...       ...
# 24336             21  2017-05-29   neutral         0       22         0
# 24337              0  2017-05-29  positive         1        0         0
# 24338             76  2017-05-29  positive        77        0         0
# 24339              0  2017-05-29   neutral         0        1         0
# 24340              0  2017-05-29  positive         1        0         0
#
# [24341 rows x 6 columns]

# %%
def fillPositive(new_df):
    if new_df['sentiment'] == 'positive':
        value = new_df['retweet_count']+1
        return value
    else:
        return 0

# %%
def fillNeutral(new_df):
    if new_df['sentiment'] == 'neutral':
        value = new_df['retweet_count']+1
        return value
    else:
        return 0

# %%
def fillNegative(new_df):
    if new_df['sentiment'] == 'negative':
        value = new_df['retweet_count']+1
        return value
    else:
        return 0

# %%
new_df['positive'] = new_df.apply(fillPositive, axis=1)

# %%
new_df['neutral'] = new_df.apply(fillNeutral, axis=1)

# %%
new_df['negative'] = new_df.apply(fillNegative, axis=1)

# %%
new_df.groupby(['created_at']);

# %%
new_df = new_df.drop(labels=['retweet_count','sentiment'],axis=1)

# %%
new_df = new_df.groupby('created_at').sum()

# %%
# Export comma-separated variable file (just in case)
new_df.to_csv('DATE-SENTIMENT.csv', index=False)
